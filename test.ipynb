# %%
# %load_ext autoreload
# %autoreload 2
import Visualizations


#MAKES THE DATA
data_fav = Visualizations.make_data_set("favorite_anime.csv")
data_pop = Visualizations.make_data_set("popular_anime.csv")

#COMBINDES THE DATA
data = Visualizations.combine_data_sets(data_fav, data_pop)

#VISUALIZATION 1
Visualizations.make_scatter_plot(data)

Visualizations.analyze_scatter_plot(data)

#VISUALIZATION 2
Visualizations.make_wordcloud(data)
# say something about how we can visually see that aot on top

#VISUALIZATION 3
Visualizations.make_bar_graph(data)
# say something about how one peice alot or somehitng :3


#print(data)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Rank                                                         1
# Title                         Fullmetal Alchemist: Brotherhood
# Rating                                                    9.09
# Image_URL    https://cdn.myanimelist.net/r/50x70/images/ani...
# Episodes                                           TV (64 eps)
# Dates                                      Apr 2009 - Jul 2010
# Name: 0, dtype: object
